# %%
import matplotlib.pyplot as plt
import os
import torch
import torchvision
import numpy as np
from torch import nn
from PIL import Image
import torch.optim as optim
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader
import cv2
import torch.nn.functional as F
import torchvision.transforms as T
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset
from pytorch_grad_cam import GradCAM, AblationCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
from shutil import copyfile
import random
import time
import copy
from torch.optim import lr_scheduler

# %%
# 경로 설정
data_dir = './facescrub_periocular/facescrub_periocular'
train_dir = './facescrub_periocular/facescrub_periocular_train'
test_dir = './facescrub_periocular/facescrub_periocular_test'

# 데이터셋 분할 비율
train_ratio = 0.8

# 폴더 생성 함수
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)

# 각 사람의 폴더 내 이미지를 train과 test로 나누어 복사
def split_data(person_dir, train_dir, test_dir, train_ratio=0.8):
    images = os.listdir(person_dir)
    random.shuffle(images)
    
    train_size = int(len(images) * train_ratio)
    train_images = images[:train_size]
    test_images = images[train_size:]
    person_name = os.path.basename(person_dir)
    
    # 각 사람별 train, test 폴더 생성
    train_person_dir = os.path.join(train_dir, person_name)
    test_person_dir = os.path.join(test_dir, person_name)
    
    create_folder(train_person_dir)
    create_folder(test_person_dir)
    
    # 이미지 복사
    for img in train_images:
        copyfile(os.path.join(person_dir, img), os.path.join(train_person_dir, img))
    
    for img in test_images:
        copyfile(os.path.join(person_dir, img), os.path.join(test_person_dir, img))

# 전체 데이터를 train/test로 분할
def split_dataset(data_dir, train_dir, test_dir, train_ratio=0.8):
    create_folder(train_dir)
    create_folder(test_dir)
    
    people = os.listdir(data_dir)
    
    for person in people:
        person_dir = os.path.join(data_dir, person)
        if os.path.isdir(person_dir):
            split_data(person_dir, train_dir, test_dir, train_ratio)

# 데이터셋 분할 실행
split_dataset(data_dir, train_dir, test_dir, train_ratio)

# %%
class FACEDATASET(Dataset):
    def __init__(self, transforms=None, split="train", testnum=10):
        self.data_dir = './facescrub_periocular/facescrub_periocular'
        self.train_dir = './facescrub_periocular/facescrub_periocular_train'
        self.test_dir = './facescrub_periocular/facescrub_periocular_test'
        self.clsname = os.listdir(self.data_dir)
        self.testnum = testnum
        self.split = split
        self.transforms = transforms
        self.sample = self.get_samples()

    def get_samples(self):
        sample = {"path": [], "name": []}
        
        if self.split == "train":
            target_dir = self.train_dir
        else:
            target_dir = self.test_dir
        
        for person in self.clsname:
            person_dir = os.path.join(target_dir, person)
            if os.path.isdir(person_dir):
                images = os.listdir(person_dir)
                for img in images:
                    sample["path"].append(os.path.join(person_dir, img))
                    sample["name"].append(person)
        
        return sample

    def name2idx(self, name):
        return self.clsname.index(name)

    def __len__(self):
        return len(self.sample["path"])
    def __getitem__(self, idx):
        img_path, label = self.sample["path"][idx], self.name2idx(self.sample["name"][idx])
        image = Image.open(img_path)
        label = torch.tensor(label, dtype=torch.long)
        onehotlabel = F.one_hot(label, num_classes=len(self.clsname))
        
        if self.transforms is not None:
            image = self.transforms(image)

        return image, onehotlabel

# %%
# Specify the means and standard deviations of the three RGB channels to
# standardize each channel
normalize = torchvision.transforms.Normalize(
    [0.485, 0.456, 0.406],[0.229, 0.224, 0.225])

# Split dataset into train/test
train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomResizedCrop([50, 150], scale=(0.8, 1.2), ratio=(2.5, 3.5)),
    transforms.ToTensor(),
    normalize
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    normalize
])

train_dataset = FACEDATASET(transforms=train_transforms, split="train", testnum=10)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = FACEDATASET(transforms=test_transforms, split="test", testnum=10)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda:1

# %%
# Mixup augmentation
def mixup(data, targets, alpha):
    rand_index = torch.randperm(data.size(0))
    data_a = data
    data_b = data[rand_index]
    target_a = targets
    target_b = targets[rand_index]

    lam = torch.FloatTensor([np.random.beta(alpha, alpha)])
    data = data_a * lam + data_b * (1 - lam)
    return data, target_a, target_b, lam

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=50, p=[0.1, 0.9]):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    # History of acc and loss
    loss_hist = {"train": [], "test": []}
    acc_hist = {"train": [], "test": []}

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
                dataloader = train_dataloader
            else:
                model.eval()   # Set model to evaluate mode
                dataloader = test_dataloader

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloader:
                labels = labels.type(torch.FloatTensor)               

                optimizer.zero_grad()

                # Option selection
                option = np.random.choice(['mixup', 'naive'], p=p)

                if option == "mixup":
                    inputs, label1, label2, lam = mixup(inputs, labels, 0.5)
                    inputs = inputs.to(device)
                    label1, label2 = label1.to(device), label2.to(device)
                    lam = float(lam)                    
                else:
                    inputs = inputs.to(device)
                    labels = labels.to(device)
                with torch.set_grad_enabled(phase == 'train'):
                    # Forward
                    prediction = model(inputs)
                    _, preds = torch.max(prediction, 1)

                    if option == "naive":
                        loss = criterion(prediction, labels)
                        _, onehotlabels = torch.max(labels, 1)
                        acc = float(torch.sum(preds == onehotlabels)) / len(preds)
                    else:
                        loss = criterion(prediction, label1) * lam + criterion(prediction, label2) * (1 - lam)
                        _, onehotlabels1 = torch.max(label1, 1)
                        _, onehotlabels2 = torch.max(label2, 1)
                        acc = (lam * (preds == onehotlabels1).cpu().sum().float() +
                               (1 - lam) * (preds == onehotlabels2).cpu().sum().float()) / len(preds)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += acc * inputs.size(0)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / len(dataloader.dataset)
            epoch_acc = 100 * running_corrects / len(dataloader.dataset) 

            loss_hist[phase].append(epoch_loss)
            acc_hist[phase].append(epoch_acc)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.2f}')

            # Deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model, loss_hist, acc_hist

# %%
# # Visualize samples
# import torch
# from torchvision.utils import make_grid
# import matplotlib.pyplot as plt

# data_iter = iter(train_dataloader)
# images, labels = next(data_iter)
# images, _, _, _ = mixup(images, labels, 1.0)

# image_grid = make_grid(images, nrow=4).numpy().transpose(1, 2, 0)

# plt.figure(figsize=(15, 5))
# plt.imshow(image_grid)
# plt.axis('off')
# plt.show()

# %%
# # Load pretrained ResNet18 model
# model_retrain = models.resnet18(weights=True)
# for param in model_retrain.parameters():
#     param.requires_grad = False
# for param in model_retrain.layer4[1].parameters():
#     param.requires_grad = True
# fc_in_features = model_retrain.fc.in_features

# model_retrain.fc = nn.Linear(fc_in_features, 100)

# %% [markdown]
# fc layer만 train

# %%
# Load pretrained ResNet18 model
model_ft = models.resnet18(weights=True)
# Change the pre-trained ResNet-18
model_ft.conv1 = nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
model_ft.maxpool = nn.MaxPool2d((3, 4), (1, 3))
model_ft.avgpool = nn.AdaptiveAvgPool2d((1, 1))

# Freeze all layers except the last fully connected layer
for param in model_ft.parameters():
    param.requires_grad = False

fc_in_features = model_ft.fc.in_features
model_ft.fc = nn.Linear(fc_in_features, 100)
nn.init.xavier_uniform_(model_ft.fc.weight)
# Out:
# c:\Users\MILab\.conda\envs\hr\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Parameter containing:
# tensor([[ 0.0482, -0.0756,  0.0096,  ..., -0.0329,  0.0802,  0.0608],
#         [ 0.0155,  0.0094,  0.0667,  ..., -0.0429, -0.0592,  0.0395],
#         [ 0.0986,  0.0556, -0.0494,  ...,  0.0341, -0.0799,  0.0450],
#         ...,
#         [ 0.0117, -0.0342, -0.0854,  ..., -0.0432, -0.0895,  0.0540],
#         [ 0.0749,  0.0940, -0.0668,  ..., -0.0605, -0.0407, -0.0205],
#         [ 0.0908, -0.0077,  0.0010,  ...,  0.0401,  0.0973,  0.0214]],
#        requires_grad=True)

# %% [markdown]
# soft max layer만 train

# %%
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model_ft.parameters(), lr=1e-3)
exp_lr_scheduler = lr_scheduler.CosineAnnealingLR(optimizer_ft, T_max=100)
model_softmax, loss_history_ft, acc_history_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 4.9523 Acc: 2.52
# test Loss: 4.5321 Acc: 4.84
# Epoch 1/99
# ----------
# train Loss: 4.3523 Acc: 6.57
# test Loss: 4.2481 Acc: 8.54
# Epoch 2/99
# ----------
# train Loss: 3.9967 Acc: 11.95
# test Loss: 4.0206 Acc: 10.42
# Epoch 3/99
# ----------
# train Loss: 3.7619 Acc: 15.83
# test Loss: 3.8921 Acc: 13.92
# Epoch 4/99
# ----------
# train Loss: 3.5389 Acc: 20.09
# test Loss: 3.7822 Acc: 14.47
# Epoch 5/99
# ----------
# train Loss: 3.4390 Acc: 22.52
# test Loss: 3.6734 Acc: 17.08
# Epoch 6/99
# ----------
# train Loss: 3.2770 Acc: 24.66
# test Loss: 3.5977 Acc: 19.34
# Epoch 7/99
# ----------
# train Loss: 3.1631 Acc: 26.08
# test Loss: 3.5867 Acc: 19.75
# Epoch 8/99
# ----------
# train Loss: 3.0447 Acc: 29.65
# test Loss: 3.5273 Acc: 20.17
# Epoch 9/99
# ----------
# train Loss: 3.0126 Acc: 30.77
# test Loss: 3.4835 Acc: 21.77
# Epoch 10/99
# ----------
# train Loss: 2.9868 Acc: 30.63
# test Loss: 3.4701 Acc: 23.13
# Epoch 11/99
# ----------
# train Loss: 2.8889 Acc: 32.42
# test Loss: 3.4565 Acc: 22.59
# Epoch 12/99
# ----------
# train Loss: 2.8104 Acc: 34.15
# test Loss: 3.3933 Acc: 23.29
# Epoch 13/99
# ----------
# train Loss: 2.7632 Acc: 34.86
# test Loss: 3.3742 Acc: 22.47
# Epoch 14/99
# ----------
# train Loss: 2.7189 Acc: 35.05
# test Loss: 3.4107 Acc: 23.62
# Epoch 15/99
# ----------
# train Loss: 2.6816 Acc: 36.35
# test Loss: 3.3922 Acc: 25.52
# Epoch 16/99
# ----------
# train Loss: 2.6964 Acc: 35.83
# test Loss: 3.4101 Acc: 24.21
# Epoch 17/99
# ----------
# train Loss: 2.6314 Acc: 37.78
# test Loss: 3.4712 Acc: 22.40
# Epoch 18/99
# ----------
# train Loss: 2.5593 Acc: 38.91
# test Loss: 3.4071 Acc: 24.11
# Epoch 19/99
# ----------
# train Loss: 2.5201 Acc: 40.24
# test Loss: 3.3236 Acc: 25.85
# Epoch 20/99
# ----------
# train Loss: 2.5374 Acc: 40.01
# test Loss: 3.3865 Acc: 22.49
# Epoch 21/99
# ----------
# train Loss: 2.5169 Acc: 40.55
# test Loss: 3.3307 Acc: 25.82
# Epoch 22/99
# ----------
# train Loss: 2.4539 Acc: 40.85
# test Loss: 3.3210 Acc: 25.92
# Epoch 23/99
# ----------
# train Loss: 2.4394 Acc: 41.61
# test Loss: 3.3651 Acc: 24.48
# Epoch 24/99
# ----------
# train Loss: 2.3898 Acc: 42.80
# test Loss: 3.3191 Acc: 25.37
# Epoch 25/99
# ----------
# train Loss: 2.3883 Acc: 41.59
# test Loss: 3.3638 Acc: 26.17
# Epoch 26/99
# ----------
# train Loss: 2.3853 Acc: 42.69
# test Loss: 3.3367 Acc: 25.84
# Epoch 27/99
# ----------
# train Loss: 2.3499 Acc: 43.38
# test Loss: 3.3897 Acc: 26.78
# Epoch 28/99
# ----------
# train Loss: 2.2847 Acc: 43.98
# test Loss: 3.3370 Acc: 26.47
# Epoch 29/99
# ----------
# train Loss: 2.3087 Acc: 44.24
# test Loss: 3.4072 Acc: 26.60
# Epoch 30/99
# ----------
# train Loss: 2.3100 Acc: 43.49
# test Loss: 3.2990 Acc: 26.95
# Epoch 31/99
# ----------
# train Loss: 2.2657 Acc: 45.02
# test Loss: 3.3950 Acc: 24.86
# Epoch 32/99
# ----------
# train Loss: 2.3142 Acc: 43.77
# test Loss: 3.3009 Acc: 26.66
# Epoch 33/99
# ----------
# train Loss: 2.3075 Acc: 44.11
# test Loss: 3.3401 Acc: 28.00
# Epoch 34/99
# ----------
# train Loss: 2.2407 Acc: 46.94
# test Loss: 3.2431 Acc: 28.83
# Epoch 35/99
# ----------
# train Loss: 2.2152 Acc: 46.11
# test Loss: 3.3145 Acc: 26.32
# Epoch 36/99
# ----------
# train Loss: 2.1958 Acc: 45.93
# test Loss: 3.2603 Acc: 27.56
# Epoch 37/99
# ----------
# train Loss: 2.2328 Acc: 45.17
# test Loss: 3.3067 Acc: 27.05
# Epoch 38/99
# ----------
# train Loss: 2.2159 Acc: 46.44
# test Loss: 3.3091 Acc: 26.96
# Epoch 39/99
# ----------
# train Loss: 2.2526 Acc: 45.68
# test Loss: 3.2964 Acc: 27.50
# Epoch 40/99
# ----------
# train Loss: 2.2099 Acc: 46.41
# test Loss: 3.2235 Acc: 28.62
# Epoch 41/99
# ----------
# train Loss: 2.2429 Acc: 46.65
# test Loss: 3.2282 Acc: 27.87
# Epoch 42/99
# ----------
# train Loss: 2.2573 Acc: 45.29
# test Loss: 3.2859 Acc: 28.15
# Epoch 43/99
# ----------
# train Loss: 2.1853 Acc: 47.61
# test Loss: 3.3444 Acc: 26.81
# Epoch 44/99
# ----------
# train Loss: 2.1211 Acc: 48.80
# test Loss: 3.2857 Acc: 27.45
# Epoch 45/99
# ----------
# train Loss: 2.1481 Acc: 47.64
# test Loss: 3.2964 Acc: 26.89
# Epoch 46/99
# ----------
# train Loss: 2.1418 Acc: 47.37
# test Loss: 3.2874 Acc: 27.40
# Epoch 47/99
# ----------
# train Loss: 2.1847 Acc: 46.86
# test Loss: 3.2784 Acc: 28.80
# Epoch 48/99
# ----------
# train Loss: 2.1359 Acc: 47.47
# test Loss: 3.2336 Acc: 28.47
# Epoch 49/99
# ----------
# train Loss: 2.1363 Acc: 48.32
# test Loss: 3.2619 Acc: 28.78
# Epoch 50/99
# ----------
# train Loss: 2.1428 Acc: 48.28
# test Loss: 3.2453 Acc: 29.25
# Epoch 51/99
# ----------
# train Loss: 2.1999 Acc: 47.28
# test Loss: 3.3067 Acc: 28.95
# Epoch 52/99
# ----------
# train Loss: 2.0684 Acc: 49.33
# test Loss: 3.2538 Acc: 28.40
# Epoch 53/99
# ----------
# train Loss: 2.0009 Acc: 49.97
# test Loss: 3.2415 Acc: 29.66
# Epoch 54/99
# ----------
# train Loss: 2.0851 Acc: 49.27
# test Loss: 3.2266 Acc: 29.15
# Epoch 55/99
# ----------
# train Loss: 2.0190 Acc: 50.69
# test Loss: 3.3081 Acc: 29.59
# Epoch 56/99
# ----------
# train Loss: 2.1227 Acc: 48.75
# test Loss: 3.2933 Acc: 28.34
# Epoch 57/99
# ----------
# train Loss: 2.0002 Acc: 51.15
# test Loss: 3.2960 Acc: 28.39
# Epoch 58/99
# ----------
# train Loss: 2.0093 Acc: 50.97
# test Loss: 3.2479 Acc: 28.84
# Epoch 59/99
# ----------
# train Loss: 2.0103 Acc: 50.60
# test Loss: 3.3039 Acc: 27.81
# Epoch 60/99
# ----------
# train Loss: 2.1108 Acc: 50.16
# test Loss: 3.2496 Acc: 29.71
# Epoch 61/99
# ----------
# train Loss: 2.1346 Acc: 49.22
# test Loss: 3.2973 Acc: 28.89
# Epoch 62/99
# ----------
# train Loss: 1.9830 Acc: 51.52
# test Loss: 3.2277 Acc: 29.68
# Epoch 63/99
# ----------
# train Loss: 1.9899 Acc: 51.27
# test Loss: 3.2435 Acc: 28.72
# Epoch 64/99
# ----------
# train Loss: 2.0272 Acc: 51.75
# test Loss: 3.1849 Acc: 30.06
# Epoch 65/99
# ----------
# train Loss: 1.9289 Acc: 52.67
# test Loss: 3.2498 Acc: 28.93
# Epoch 66/99
# ----------
# train Loss: 1.9731 Acc: 51.82
# test Loss: 3.3097 Acc: 29.04
# Epoch 67/99
# ----------
# train Loss: 2.0559 Acc: 50.45
# test Loss: 3.3064 Acc: 29.04
# Epoch 68/99
# ----------
# train Loss: 1.9813 Acc: 51.65
# test Loss: 3.2010 Acc: 29.76
# Epoch 69/99
# ----------
# train Loss: 1.9430 Acc: 51.85
# test Loss: 3.2738 Acc: 28.96
# Epoch 70/99
# ----------
# train Loss: 1.9587 Acc: 52.24
# test Loss: 3.2637 Acc: 29.29
# Epoch 71/99
# ----------
# train Loss: 1.9975 Acc: 51.72
# test Loss: 3.2519 Acc: 29.29
# Epoch 72/99
# ----------
# train Loss: 2.0531 Acc: 50.07
# test Loss: 3.1697 Acc: 30.05
# Epoch 73/99
# ----------
# train Loss: 1.9252 Acc: 52.78
# test Loss: 3.2168 Acc: 29.77
# Epoch 74/99
# ----------
# train Loss: 1.9960 Acc: 52.07
# test Loss: 3.2598 Acc: 28.56
# Epoch 75/99
# ----------
# train Loss: 1.9011 Acc: 53.07
# test Loss: 3.2127 Acc: 29.42
# Epoch 76/99
# ----------
# train Loss: 1.9294 Acc: 52.78
# test Loss: 3.2513 Acc: 28.86
# Epoch 77/99
# ----------
# train Loss: 1.9669 Acc: 51.65
# test Loss: 3.2343 Acc: 29.11
# Epoch 78/99
# ----------
# train Loss: 2.0112 Acc: 51.41
# test Loss: 3.2056 Acc: 30.26
# Epoch 79/99
# ----------
# train Loss: 1.9945 Acc: 52.75
# test Loss: 3.2299 Acc: 29.50
# Epoch 80/99
# ----------
# train Loss: 1.9265 Acc: 53.73
# test Loss: 3.2556 Acc: 28.08
# Epoch 81/99
# ----------
# train Loss: 1.9422 Acc: 53.92
# test Loss: 3.3446 Acc: 27.52
# Epoch 82/99
# ----------
# train Loss: 1.9868 Acc: 52.04
# test Loss: 3.2530 Acc: 29.23
# Epoch 83/99
# ----------
# train Loss: 1.9880 Acc: 52.45
# test Loss: 3.3126 Acc: 28.47
# Epoch 84/99
# ----------
# train Loss: 1.9643 Acc: 52.55
# test Loss: 3.1691 Acc: 30.46
# Epoch 85/99
# ----------
# train Loss: 1.8803 Acc: 52.86
# test Loss: 3.1615 Acc: 30.65
# Epoch 86/99
# ----------
# train Loss: 1.9294 Acc: 53.51
# test Loss: 3.1703 Acc: 30.60
# Epoch 87/99
# ----------
# train Loss: 1.9310 Acc: 52.66
# test Loss: 3.1676 Acc: 30.13
# Epoch 88/99
# ----------
# train Loss: 2.0364 Acc: 51.35
# test Loss: 3.1700 Acc: 29.99
# Epoch 89/99
# ----------
# train Loss: 1.9155 Acc: 53.26
# test Loss: 3.1708 Acc: 31.32
# Epoch 90/99
# ----------
# train Loss: 1.9823 Acc: 52.88
# test Loss: 3.2334 Acc: 29.64
# Epoch 91/99
# ----------
# train Loss: 1.8098 Acc: 55.35
# test Loss: 3.1308 Acc: 30.30
# Epoch 92/99
# ----------
# train Loss: 1.9072 Acc: 53.45
# test Loss: 3.1893 Acc: 29.98
# Epoch 93/99
# ----------
# train Loss: 2.0114 Acc: 51.85
# test Loss: 3.1473 Acc: 30.50
# Epoch 94/99
# ----------
# train Loss: 1.8934 Acc: 54.25
# test Loss: 3.1295 Acc: 30.80
# Epoch 95/99
# ----------
# train Loss: 1.8982 Acc: 54.67
# test Loss: 3.2225 Acc: 29.31
# Epoch 96/99
# ----------
# train Loss: 1.9347 Acc: 53.75
# test Loss: 3.1651 Acc: 30.00
# Epoch 97/99
# ----------
# train Loss: 1.9120 Acc: 53.10
# test Loss: 3.2060 Acc: 29.88
# Epoch 98/99
# ----------
# train Loss: 1.8842 Acc: 53.88
# test Loss: 3.2748 Acc: 28.94
# Epoch 99/99
# ----------
# train Loss: 1.8780 Acc: 53.43
# test Loss: 3.2010 Acc: 30.14
# Training complete in 11m 58s
# Best val Acc: 31.315851

# %% [markdown]
# conv5만 train

# %%
# Load pretrained ResNet18 model
model_ft = models.resnet18(pretrained=True)

# Modify the initial layers
model_ft.conv1 = nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
model_ft.maxpool = nn.MaxPool2d((3, 4), (1, 3))
model_ft.avgpool = nn.AdaptiveAvgPool2d((1, 1))

# Freeze all layers except for the conv5_x block and the final fully connected layer
for name, param in model_ft.named_parameters():
    if not name.startswith('layer4'):  # layer4 corresponds to conv5_x in ResNet-18
        param.requires_grad = False

# Replace the fully connected layer
fc_in_features = model_ft.fc.in_features
model_ft.fc = nn.Linear(fc_in_features, 100)
nn.init.xavier_uniform_(model_ft.fc.weight)

# %% [markdown]
# conv_5만 train

# %%
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model_ft.parameters(), lr=1e-3)
exp_lr_scheduler = lr_scheduler.CosineAnnealingLR(optimizer_ft, T_max=100)
model_conv5, loss_history_conv5, acc_history_conv5 = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=100)

# %% [markdown]
# finetune all conv layer(1e-3)

# %%
# Load pretrained ResNet18 model
model_ft = models.resnet18(pretrained=True)

# Modify the initial layers
model_ft.conv1 = nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
model_ft.maxpool = nn.MaxPool2d((3, 4), (1, 3))
model_ft.avgpool = nn.AdaptiveAvgPool2d((1, 1))

# Ensure all layers are trainable
for param in model_ft.parameters():
    param.requires_grad = True

# Replace the fully connected layer
fc_in_features = model_ft.fc.in_features
model_ft.fc = nn.Linear(fc_in_features, 100)
nn.init.xavier_uniform_(model_ft.fc.weight)
# Out:
# c:\Users\MILab\.conda\envs\hr\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\MILab\.conda\envs\hr\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Parameter containing:
# tensor([[-0.0712, -0.0484,  0.0137,  ...,  0.0785, -0.0077, -0.0949],
#         [ 0.0698, -0.0220, -0.0481,  ..., -0.0703,  0.0769,  0.0361],
#         [ 0.0930, -0.0196, -0.0552,  ...,  0.0946, -0.0268, -0.0562],
#         ...,
#         [ 0.0866, -0.0328, -0.0385,  ...,  0.0383,  0.0663,  0.0393],
#         [ 0.0442, -0.0704,  0.0025,  ...,  0.0387,  0.0091,  0.0570],
#         [-0.0365, -0.0059,  0.0075,  ..., -0.0779,  0.0826,  0.0171]],
#        requires_grad=True)

# %% [markdown]
# Fine-tune ALL convolution layers

# %%
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model_ft.parameters(), lr=1e-3)
exp_lr_scheduler = lr_scheduler.CosineAnnealingLR(optimizer_ft, T_max=100)
model_ft_all, loss_history_ft_all, acc_history_ft_all = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 4.1039 Acc: 10.71
# test Loss: 3.7465 Acc: 14.63
# Epoch 1/99
# ----------
# train Loss: 2.6737 Acc: 33.85
# test Loss: 2.1629 Acc: 44.07
# Epoch 2/99
# ----------
# train Loss: 1.8256 Acc: 53.41
# test Loss: 2.2669 Acc: 44.18
# Epoch 3/99
# ----------
# train Loss: 1.3602 Acc: 66.38
# test Loss: 1.5499 Acc: 61.47
# Epoch 4/99
# ----------
# train Loss: 1.0693 Acc: 73.37
# test Loss: 1.6099 Acc: 62.95
# Epoch 5/99
# ----------
# train Loss: 0.8143 Acc: 79.96
# test Loss: 1.1224 Acc: 72.61
# Epoch 6/99
# ----------
# train Loss: 0.7932 Acc: 81.90
# test Loss: 1.5616 Acc: 64.80
# Epoch 7/99
# ----------
# train Loss: 0.6173 Acc: 86.04
# test Loss: 1.1205 Acc: 75.71
# Epoch 8/99
# ----------
# train Loss: 0.6282 Acc: 87.26
# test Loss: 1.3548 Acc: 70.85
# Epoch 9/99
# ----------
# train Loss: 0.4611 Acc: 90.67
# test Loss: 0.8758 Acc: 79.10
# Epoch 10/99
# ----------
# train Loss: 0.4005 Acc: 90.72
# test Loss: 1.2526 Acc: 72.80
# Epoch 11/99
# ----------
# train Loss: 0.4629 Acc: 90.88
# test Loss: 0.9453 Acc: 80.17
# Epoch 12/99
# ----------
# train Loss: 0.4953 Acc: 90.99
# test Loss: 0.8565 Acc: 79.01
# Epoch 13/99
# ----------
# train Loss: 0.3861 Acc: 93.10
# test Loss: 1.0166 Acc: 76.20
# Epoch 14/99
# ----------
# train Loss: 0.3528 Acc: 94.07
# test Loss: 0.9928 Acc: 78.70
# Epoch 15/99
# ----------
# train Loss: 0.2661 Acc: 95.03
# test Loss: 0.8683 Acc: 81.60
# Epoch 16/99
# ----------
# train Loss: 0.3375 Acc: 94.56
# test Loss: 0.9918 Acc: 80.10
# Epoch 17/99
# ----------
# train Loss: 0.1186 Acc: 97.93
# test Loss: 0.9641 Acc: 79.31
# Epoch 18/99
# ----------
# train Loss: 0.2589 Acc: 96.30
# test Loss: 0.7932 Acc: 81.98
# Epoch 19/99
# ----------
# train Loss: 0.3399 Acc: 93.77
# test Loss: 0.9682 Acc: 80.10
# Epoch 20/99
# ----------
# train Loss: 0.3824 Acc: 94.04
# test Loss: 1.1075 Acc: 76.65
# Epoch 21/99
# ----------
# train Loss: 0.2957 Acc: 95.27
# test Loss: 1.1603 Acc: 76.99
# Epoch 22/99
# ----------
# train Loss: 0.3366 Acc: 93.59
# test Loss: 0.9697 Acc: 79.61
# Epoch 23/99
# ----------
# train Loss: 0.3483 Acc: 93.74
# test Loss: 1.0510 Acc: 76.83
# Epoch 24/99
# ----------
# train Loss: 0.2026 Acc: 97.15
# test Loss: 1.1047 Acc: 76.74
# Epoch 25/99
# ----------
# train Loss: 0.2243 Acc: 96.65
# test Loss: 1.0122 Acc: 78.26
# Epoch 26/99
# ----------
# train Loss: 0.1635 Acc: 97.55
# test Loss: 0.9283 Acc: 80.49
# Epoch 27/99
# ----------
# train Loss: 0.1803 Acc: 97.33
# test Loss: 1.0572 Acc: 78.30
# Epoch 28/99
# ----------
# train Loss: 0.2132 Acc: 97.34
# test Loss: 0.8729 Acc: 80.93
# Epoch 29/99
# ----------
# train Loss: 0.1586 Acc: 98.10
# test Loss: 0.7468 Acc: 83.28
# Epoch 30/99
# ----------
# train Loss: 0.2713 Acc: 96.32
# test Loss: 0.8951 Acc: 79.86
# Epoch 31/99
# ----------
# train Loss: 0.2083 Acc: 97.02
# test Loss: 0.8882 Acc: 80.84
# Epoch 32/99
# ----------
# train Loss: 0.2795 Acc: 96.07
# test Loss: 0.8773 Acc: 82.35
# Epoch 33/99
# ----------
# train Loss: 0.2479 Acc: 96.73
# test Loss: 0.7480 Acc: 84.02
# Epoch 34/99
# ----------
# train Loss: 0.1530 Acc: 98.26
# test Loss: 0.7086 Acc: 83.47
# Epoch 35/99
# ----------
# train Loss: 0.2160 Acc: 97.51
# test Loss: 0.8044 Acc: 83.41
# Epoch 36/99
# ----------
# train Loss: 0.1751 Acc: 97.47
# test Loss: 1.0942 Acc: 78.97
# Epoch 37/99
# ----------
# train Loss: 0.2824 Acc: 96.02
# test Loss: 0.9364 Acc: 79.16
# Epoch 38/99
# ----------
# train Loss: 0.2234 Acc: 96.76
# test Loss: 0.7160 Acc: 83.74
# Epoch 39/99
# ----------
# train Loss: 0.1651 Acc: 98.19
# test Loss: 0.8772 Acc: 81.78
# Epoch 40/99
# ----------
# train Loss: 0.2145 Acc: 97.73
# test Loss: 0.5907 Acc: 85.86
# Epoch 41/99
# ----------
# train Loss: 0.2982 Acc: 95.37
# test Loss: 0.8627 Acc: 80.67
# Epoch 42/99
# ----------
# train Loss: 0.2624 Acc: 96.23
# test Loss: 1.0304 Acc: 79.44
# Epoch 43/99
# ----------
# train Loss: 0.3979 Acc: 94.10
# test Loss: 0.7154 Acc: 83.52
# Epoch 44/99
# ----------
# train Loss: 0.1794 Acc: 97.80
# test Loss: 0.7464 Acc: 84.14
# Epoch 45/99
# ----------
# train Loss: 0.2348 Acc: 97.24
# test Loss: 0.8473 Acc: 81.38
# Epoch 46/99
# ----------
# train Loss: 0.2232 Acc: 97.21
# test Loss: 0.7167 Acc: 84.14
# Epoch 47/99
# ----------
# train Loss: 0.1170 Acc: 98.26
# test Loss: 1.0536 Acc: 78.98
# Epoch 48/99
# ----------
# train Loss: 0.1466 Acc: 98.19
# test Loss: 0.6010 Acc: 85.72
# Epoch 49/99
# ----------
# train Loss: 0.1515 Acc: 98.07
# test Loss: 0.6074 Acc: 86.36
# Epoch 50/99
# ----------
# train Loss: 0.1985 Acc: 97.47
# test Loss: 0.7095 Acc: 85.42
# Epoch 51/99
# ----------
# train Loss: 0.1316 Acc: 98.46
# test Loss: 0.7763 Acc: 81.29
# Epoch 52/99
# ----------
# train Loss: 0.2403 Acc: 96.56
# test Loss: 0.8604 Acc: 81.90
# Epoch 53/99
# ----------
# train Loss: 0.2483 Acc: 96.92
# test Loss: 0.6192 Acc: 85.74
# Epoch 54/99
# ----------
# train Loss: 0.2075 Acc: 97.04
# test Loss: 0.5972 Acc: 86.16
# Epoch 55/99
# ----------
# train Loss: 0.1628 Acc: 97.98
# test Loss: 0.6204 Acc: 85.48
# Epoch 56/99
# ----------
# train Loss: 0.1364 Acc: 98.52
# test Loss: 0.7242 Acc: 84.72
# Epoch 57/99
# ----------
# train Loss: 0.1876 Acc: 97.28
# test Loss: 0.6284 Acc: 85.77
# Epoch 58/99
# ----------
# train Loss: 0.1129 Acc: 98.85
# test Loss: 0.8605 Acc: 81.88
# Epoch 59/99
# ----------
# train Loss: 0.1475 Acc: 97.85
# test Loss: 0.5688 Acc: 87.48
# Epoch 60/99
# ----------
# train Loss: 0.1668 Acc: 97.92
# test Loss: 0.7440 Acc: 83.68
# Epoch 61/99
# ----------
# train Loss: 0.1806 Acc: 97.61
# test Loss: 0.7269 Acc: 84.01
# Epoch 62/99
# ----------
# train Loss: 0.2041 Acc: 97.23
# test Loss: 0.6588 Acc: 85.49
# Epoch 63/99
# ----------
# train Loss: 0.1246 Acc: 98.02
# test Loss: 0.5219 Acc: 88.18
# Epoch 64/99
# ----------
# train Loss: 0.1374 Acc: 98.14
# test Loss: 0.6003 Acc: 87.41
# Epoch 65/99
# ----------
# train Loss: 0.0970 Acc: 98.81
# test Loss: 0.5134 Acc: 88.56
# Epoch 66/99
# ----------
# train Loss: 0.1871 Acc: 97.28
# test Loss: 0.7406 Acc: 83.14
# Epoch 67/99
# ----------
# train Loss: 0.1735 Acc: 97.79
# test Loss: 0.4971 Acc: 88.65
# Epoch 68/99
# ----------
# train Loss: 0.1174 Acc: 98.05
# test Loss: 0.5900 Acc: 86.13
# Epoch 69/99
# ----------
# train Loss: 0.2260 Acc: 96.88
# test Loss: 0.6921 Acc: 85.39
# Epoch 70/99
# ----------
# train Loss: 0.0974 Acc: 98.36
# test Loss: 0.6997 Acc: 84.76
# Epoch 71/99
# ----------
# train Loss: 0.1731 Acc: 97.98
# test Loss: 0.6194 Acc: 87.22
# Epoch 72/99
# ----------
# train Loss: 0.1843 Acc: 96.79
# test Loss: 0.7788 Acc: 83.81
# Epoch 73/99
# ----------
# train Loss: 0.1660 Acc: 97.56
# test Loss: 0.5103 Acc: 89.06
# Epoch 74/99
# ----------
# train Loss: 0.1899 Acc: 97.12
# test Loss: 0.5498 Acc: 87.39
# Epoch 75/99
# ----------
# train Loss: 0.1128 Acc: 98.48
# test Loss: 0.5629 Acc: 87.15
# Epoch 76/99
# ----------
# train Loss: 0.1891 Acc: 97.41
# test Loss: 0.5308 Acc: 88.29
# Epoch 77/99
# ----------
# train Loss: 0.1136 Acc: 98.35
# test Loss: 0.6030 Acc: 85.94
# Epoch 78/99
# ----------
# train Loss: 0.2252 Acc: 97.00
# test Loss: 0.6705 Acc: 85.99
# Epoch 79/99
# ----------
# train Loss: 0.0716 Acc: 99.01
# test Loss: 0.7347 Acc: 84.91
# Epoch 80/99
# ----------
# train Loss: 0.2749 Acc: 95.43
# test Loss: 0.7456 Acc: 84.32
# Epoch 81/99
# ----------
# train Loss: 0.1266 Acc: 98.04
# test Loss: 0.6719 Acc: 85.01
# Epoch 82/99
# ----------
# train Loss: 0.0701 Acc: 98.72
# test Loss: 0.5609 Acc: 86.88
# Epoch 83/99
# ----------
# train Loss: 0.1043 Acc: 98.58
# test Loss: 0.7029 Acc: 85.19
# Epoch 84/99
# ----------
# train Loss: 0.1681 Acc: 97.51
# test Loss: 0.8195 Acc: 83.11
# Epoch 85/99
# ----------
# train Loss: 0.2020 Acc: 96.81
# test Loss: 0.5340 Acc: 87.90
# Epoch 86/99
# ----------
# train Loss: 0.1621 Acc: 97.49
# test Loss: 0.6236 Acc: 86.29
# Epoch 87/99
# ----------
# train Loss: 0.1756 Acc: 97.05
# test Loss: 0.5306 Acc: 88.18
# Epoch 88/99
# ----------
# train Loss: 0.1593 Acc: 97.43
# test Loss: 0.4808 Acc: 88.93
# Epoch 89/99
# ----------
# train Loss: 0.1522 Acc: 97.39
# test Loss: 0.6097 Acc: 86.09
# Epoch 90/99
# ----------
# train Loss: 0.1618 Acc: 97.42
# test Loss: 0.6556 Acc: 86.34
# Epoch 91/99
# ----------
# train Loss: 0.1653 Acc: 97.19
# test Loss: 0.5592 Acc: 87.10
# Epoch 92/99
# ----------
# train Loss: 0.2493 Acc: 95.55
# test Loss: 0.4828 Acc: 88.50
# Epoch 93/99
# ----------
# train Loss: 0.0943 Acc: 98.84
# test Loss: 0.5133 Acc: 88.22
# Epoch 94/99
# ----------
# train Loss: 0.1648 Acc: 97.55
# test Loss: 0.5908 Acc: 87.40
# Epoch 95/99
# ----------
# train Loss: 0.0471 Acc: 99.47
# test Loss: 0.4992 Acc: 88.69
# Epoch 96/99
# ----------
# train Loss: 0.1530 Acc: 97.42
# test Loss: 0.5679 Acc: 87.05
# Epoch 97/99
# ----------
# train Loss: 0.1433 Acc: 97.90
# test Loss: 0.4973 Acc: 88.77
# Epoch 98/99
# ----------
# train Loss: 0.0973 Acc: 98.86
# test Loss: 0.6169 Acc: 85.99
# Epoch 99/99
# ----------
# train Loss: 0.1982 Acc: 97.15
# test Loss: 0.5561 Acc: 86.99
# Training complete in 17m 22s
# Best val Acc: 89.060196

# %% [markdown]
# Retrain from scratch

# %%
# Load ResNet18 model without pretrained weights
model_ft = models.resnet18(pretrained=False)

# Modify the initial layers
model_ft.conv1 = nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
model_ft.maxpool = nn.MaxPool2d((3, 4), (1, 3))
model_ft.avgpool = nn.AdaptiveAvgPool2d((1, 1))

# Ensure all layers are trainable (by default, this will be the case)
for param in model_ft.parameters():
    param.requires_grad = True

# Replace the fully connected layer
fc_in_features = model_ft.fc.in_features
model_ft.fc = nn.Linear(fc_in_features, 100)
nn.init.xavier_uniform_(model_ft.fc.weight)

# Initialize weights for convolutional layers (optional but recommended for training from scratch)
def initialize_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)

model_ft.apply(initialize_weights)
# Out:
# c:\Users\MILab\.conda\envs\hr\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=(3, 4), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )

# %% [markdown]
# Retrain the whole model from scratch.

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = '0, 1'
# model_ft = torch.nn.DataParallel(model_ft, output_device=1).to(device)
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model_ft.parameters(), lr=5e-3)
exp_lr_scheduler = lr_scheduler.CosineAnnealingLR(optimizer_ft, T_max=100)
model_rt, loss_history_rt, acc_history_rt = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 5.0417 Acc: 1.77
# test Loss: 4.7008 Acc: 2.20
# Epoch 1/99
# ----------
# train Loss: 4.4987 Acc: 2.32
# test Loss: 4.5612 Acc: 3.40
# Epoch 2/99
# ----------
# train Loss: 4.2618 Acc: 4.50
# test Loss: 4.2295 Acc: 4.76
# Epoch 3/99
# ----------
# train Loss: 4.0279 Acc: 6.26
# test Loss: 3.8937 Acc: 6.97
# Epoch 4/99
# ----------
# train Loss: 3.7884 Acc: 9.68
# test Loss: 3.6951 Acc: 12.41
# Epoch 5/99
# ----------
# train Loss: 3.5351 Acc: 13.97
# test Loss: 3.7337 Acc: 11.66
# Epoch 6/99
# ----------
# train Loss: 3.3034 Acc: 17.84
# test Loss: 3.3730 Acc: 18.70
# Epoch 7/99
# ----------
# train Loss: 3.0109 Acc: 23.87
# test Loss: 3.1894 Acc: 23.78
# Epoch 8/99
# ----------
# train Loss: 2.7594 Acc: 29.54
# test Loss: 3.3308 Acc: 22.19
# Epoch 9/99
# ----------
# train Loss: 2.5155 Acc: 36.54
# test Loss: 2.5729 Acc: 36.30
# Epoch 10/99
# ----------
# train Loss: 2.1892 Acc: 45.27
# test Loss: 2.5257 Acc: 39.18
# Epoch 11/99
# ----------
# train Loss: 1.8521 Acc: 52.81
# test Loss: 2.2023 Acc: 45.02
# Epoch 12/99
# ----------
# train Loss: 1.7460 Acc: 56.13
# test Loss: 1.9674 Acc: 53.51
# Epoch 13/99
# ----------
# train Loss: 1.4840 Acc: 61.24
# test Loss: 2.2434 Acc: 44.94
# Epoch 14/99
# ----------
# train Loss: 1.2192 Acc: 67.46
# test Loss: 1.9763 Acc: 55.16
# Epoch 15/99
# ----------
# train Loss: 1.1747 Acc: 70.05
# test Loss: 1.7320 Acc: 55.77
# Epoch 16/99
# ----------
# train Loss: 1.0001 Acc: 74.67
# test Loss: 1.4756 Acc: 66.29
# Epoch 17/99
# ----------
# train Loss: 0.8399 Acc: 78.04
# test Loss: 1.4329 Acc: 65.31
# Epoch 18/99
# ----------
# train Loss: 1.0381 Acc: 76.41
# test Loss: 1.4517 Acc: 65.16
# Epoch 19/99
# ----------
# train Loss: 0.6760 Acc: 83.97
# test Loss: 1.6293 Acc: 61.85
# Epoch 20/99
# ----------
# train Loss: 0.6801 Acc: 84.63
# test Loss: 1.4987 Acc: 67.13
# Epoch 21/99
# ----------
# train Loss: 0.5846 Acc: 87.61
# test Loss: 1.2691 Acc: 69.31
# Epoch 22/99
# ----------
# train Loss: 0.5396 Acc: 89.03
# test Loss: 1.3755 Acc: 67.96
# Epoch 23/99
# ----------
# train Loss: 0.4536 Acc: 89.56
# test Loss: 1.4835 Acc: 66.40
# Epoch 24/99
# ----------
# train Loss: 0.4872 Acc: 89.83
# test Loss: 1.3458 Acc: 68.98
# Epoch 25/99
# ----------
# train Loss: 0.4836 Acc: 90.91
# test Loss: 1.2440 Acc: 71.42
# Epoch 26/99
# ----------
# train Loss: 0.3795 Acc: 93.26
# test Loss: 1.2193 Acc: 72.27
# Epoch 27/99
# ----------
# train Loss: 0.3205 Acc: 94.67
# test Loss: 1.3792 Acc: 71.65
# Epoch 28/99
# ----------
# train Loss: 0.1748 Acc: 96.58
# test Loss: 1.1618 Acc: 74.90
# Epoch 29/99
# ----------
# train Loss: 0.4031 Acc: 93.30
# test Loss: 1.2657 Acc: 73.15
# Epoch 30/99
# ----------
# train Loss: 0.3576 Acc: 93.45
# test Loss: 1.2735 Acc: 73.72
# Epoch 31/99
# ----------
# train Loss: 0.3324 Acc: 94.51
# test Loss: 1.1917 Acc: 74.05
# Epoch 32/99
# ----------
# train Loss: 0.2117 Acc: 96.62
# test Loss: 1.3165 Acc: 73.79
# Epoch 33/99
# ----------
# train Loss: 0.2974 Acc: 95.65
# test Loss: 1.2996 Acc: 71.47
# Epoch 34/99
# ----------
# train Loss: 0.3429 Acc: 94.93
# test Loss: 0.9884 Acc: 77.43
# Epoch 35/99
# ----------
# train Loss: 0.2801 Acc: 95.75
# test Loss: 1.6397 Acc: 65.36
# Epoch 36/99
# ----------
# train Loss: 0.2681 Acc: 95.54
# test Loss: 1.1618 Acc: 74.66
# Epoch 37/99
# ----------
# train Loss: 0.3569 Acc: 94.46
# test Loss: 1.0528 Acc: 75.40
# Epoch 38/99
# ----------
# train Loss: 0.1917 Acc: 97.43
# test Loss: 1.3329 Acc: 72.83
# Epoch 39/99
# ----------
# train Loss: 0.2286 Acc: 97.22
# test Loss: 0.9730 Acc: 79.10
# Epoch 40/99
# ----------
# train Loss: 0.3138 Acc: 95.08
# test Loss: 1.0065 Acc: 75.96
# Epoch 41/99
# ----------
# train Loss: 0.2421 Acc: 96.41
# test Loss: 0.8875 Acc: 79.48
# Epoch 42/99
# ----------
# train Loss: 0.2165 Acc: 97.42
# test Loss: 1.0209 Acc: 75.46
# Epoch 43/99
# ----------
# train Loss: 0.2919 Acc: 96.40
# test Loss: 1.0620 Acc: 77.13
# Epoch 44/99
# ----------
# train Loss: 0.2276 Acc: 97.08
# test Loss: 0.8470 Acc: 80.60
# Epoch 45/99
# ----------
# train Loss: 0.2561 Acc: 96.69
# test Loss: 0.9878 Acc: 76.35
# Epoch 46/99
# ----------
# train Loss: 0.3952 Acc: 94.69
# test Loss: 1.0368 Acc: 77.23
# Epoch 47/99
# ----------
# train Loss: 0.2539 Acc: 96.43
# test Loss: 0.9974 Acc: 77.63
# Epoch 48/99
# ----------
# train Loss: 0.1641 Acc: 97.63
# test Loss: 1.0586 Acc: 76.47
# Epoch 49/99
# ----------
# train Loss: 0.1911 Acc: 97.73
# test Loss: 0.9336 Acc: 78.50
# Epoch 50/99
# ----------
# train Loss: 0.1897 Acc: 97.48
# test Loss: 0.9493 Acc: 76.97
# Epoch 51/99
# ----------
# train Loss: 0.2057 Acc: 97.18
# test Loss: 0.9437 Acc: 78.87
# Epoch 52/99
# ----------
# train Loss: 0.3336 Acc: 94.95
# test Loss: 0.9805 Acc: 77.50
# Epoch 53/99
# ----------
# train Loss: 0.1495 Acc: 98.55
# test Loss: 0.9394 Acc: 78.61
# Epoch 54/99
# ----------
# train Loss: 0.2224 Acc: 97.17
# test Loss: 1.0847 Acc: 75.80
# Epoch 55/99
# ----------
# train Loss: 0.1211 Acc: 98.71
# test Loss: 1.0967 Acc: 76.43
# Epoch 56/99
# ----------
# train Loss: 0.2351 Acc: 96.65
# test Loss: 1.2098 Acc: 75.61
# Epoch 57/99
# ----------
# train Loss: 0.1680 Acc: 97.78
# test Loss: 1.1946 Acc: 75.28
# Epoch 58/99
# ----------
# train Loss: 0.2820 Acc: 96.01
# test Loss: 0.8699 Acc: 78.40
# Epoch 59/99
# ----------
# train Loss: 0.1683 Acc: 97.96
# test Loss: 0.7688 Acc: 81.30
# Epoch 60/99
# ----------
# train Loss: 0.2441 Acc: 97.49
# test Loss: 0.9802 Acc: 77.96
# Epoch 61/99
# ----------
# train Loss: 0.2386 Acc: 97.29
# test Loss: 0.9860 Acc: 79.29
# Epoch 62/99
# ----------
# train Loss: 0.2798 Acc: 95.57
# test Loss: 0.8698 Acc: 79.60
# Epoch 63/99
# ----------
# train Loss: 0.1866 Acc: 98.03
# test Loss: 0.7568 Acc: 82.00
# Epoch 64/99
# ----------
# train Loss: 0.1632 Acc: 98.12
# test Loss: 0.8105 Acc: 80.28
# Epoch 65/99
# ----------
# train Loss: 0.1368 Acc: 98.35
# test Loss: 0.8928 Acc: 79.39
# Epoch 66/99
# ----------
# train Loss: 0.1930 Acc: 97.22
# test Loss: 0.9806 Acc: 78.07
# Epoch 67/99
# ----------
# train Loss: 0.1188 Acc: 98.49
# test Loss: 0.8593 Acc: 79.51
# Epoch 68/99
# ----------
# train Loss: 0.2191 Acc: 97.22
# test Loss: 0.8306 Acc: 80.35
# Epoch 69/99
# ----------
# train Loss: 0.1456 Acc: 97.95
# test Loss: 0.8237 Acc: 80.72
# Epoch 70/99
# ----------
# train Loss: 0.1938 Acc: 97.18
# test Loss: 0.9567 Acc: 79.23
# Epoch 71/99
# ----------
# train Loss: 0.1536 Acc: 97.85
# test Loss: 0.7493 Acc: 81.90
# Epoch 72/99
# ----------
# train Loss: 0.0925 Acc: 98.87
# test Loss: 0.7757 Acc: 82.06
# Epoch 73/99
# ----------
# train Loss: 0.1923 Acc: 97.17
# test Loss: 0.9056 Acc: 79.40
# Epoch 74/99
# ----------
# train Loss: 0.1611 Acc: 97.79
# test Loss: 0.7640 Acc: 81.42
# Epoch 75/99
# ----------
# train Loss: 0.2445 Acc: 96.03
# test Loss: 1.0285 Acc: 78.98
# Epoch 76/99
# ----------
# train Loss: 0.1664 Acc: 97.77
# test Loss: 0.8195 Acc: 81.22
# Epoch 77/99
# ----------
# train Loss: 0.1801 Acc: 97.17
# test Loss: 0.8435 Acc: 82.01
# Epoch 78/99
# ----------
# train Loss: 0.1290 Acc: 98.35
# test Loss: 0.7077 Acc: 82.30
# Epoch 79/99
# ----------
# train Loss: 0.1702 Acc: 97.43
# test Loss: 0.7608 Acc: 82.32
# Epoch 80/99
# ----------
# train Loss: 0.0916 Acc: 99.00
# test Loss: 0.6891 Acc: 83.94
# Epoch 81/99
# ----------
# train Loss: 0.1580 Acc: 98.21
# test Loss: 0.9492 Acc: 79.35
# Epoch 82/99
# ----------
# train Loss: 0.1492 Acc: 97.89
# test Loss: 0.7517 Acc: 81.68
# Epoch 83/99
# ----------
# train Loss: 0.2011 Acc: 96.97
# test Loss: 0.7571 Acc: 82.40
# Epoch 84/99
# ----------
# train Loss: 0.1884 Acc: 97.15
# test Loss: 0.6770 Acc: 83.90
# Epoch 85/99
# ----------
# train Loss: 0.2765 Acc: 95.33
# test Loss: 0.7406 Acc: 82.45
# Epoch 86/99
# ----------
# train Loss: 0.1872 Acc: 97.73
# test Loss: 0.7643 Acc: 82.50
# Epoch 87/99
# ----------
# train Loss: 0.2118 Acc: 97.22
# test Loss: 0.8307 Acc: 81.14
# Epoch 88/99
# ----------
# train Loss: 0.1193 Acc: 98.63
# test Loss: 0.8236 Acc: 81.75
# Epoch 89/99
# ----------
# train Loss: 0.1677 Acc: 97.73
# test Loss: 0.7016 Acc: 84.00
# Epoch 90/99
# ----------
# train Loss: 0.1591 Acc: 98.15
# test Loss: 0.8315 Acc: 80.21
# Epoch 91/99
# ----------
# train Loss: 0.1375 Acc: 97.98
# test Loss: 0.8435 Acc: 80.73
# Epoch 92/99
# ----------
# train Loss: 0.2014 Acc: 96.92
# test Loss: 0.7490 Acc: 82.74
# Epoch 93/99
# ----------
# train Loss: 0.1541 Acc: 97.41
# test Loss: 0.8246 Acc: 81.19
# Epoch 94/99
# ----------
# train Loss: 0.1512 Acc: 98.02
# test Loss: 0.6632 Acc: 83.70
# Epoch 95/99
# ----------
# train Loss: 0.2233 Acc: 96.42
# test Loss: 0.8980 Acc: 79.77
# Epoch 96/99
# ----------
# train Loss: 0.1315 Acc: 98.00
# test Loss: 0.8235 Acc: 82.03
# Epoch 97/99
# ----------
# train Loss: 0.1176 Acc: 98.44
# test Loss: 0.8241 Acc: 81.92
# Epoch 98/99
# ----------
# train Loss: 0.1698 Acc: 97.73
# test Loss: 0.7928 Acc: 81.64
# Epoch 99/99
# ----------
# train Loss: 0.2411 Acc: 96.58
# test Loss: 0.6979 Acc: 83.28
# Training complete in 17m 15s
# Best val Acc: 84.000671

# %% [markdown]
# Training complete in 17m 32s 96.09 Best val Acc: 85.145653 with lr 1e-2
# Training complete in  Best val Acc: 87.29  with lr 5e-3
# Training complete in  Best val Acc: 84.56 with lr 1e-3
# Training complete in  Best val Acc:   with lr 1e-4

# %%
import matplotlib.pyplot as plt

# Assuming loss_hist and acc_hist are obtained from the training function
# loss_hist = {'train': [...], 'test': [...]}
# acc_hist = {'train': [...], 'test': [...]}

def plot_training_history(loss_hist, acc_hist):
    epochs = range(len(loss_hist['train']))

    plt.figure(figsize=(12, 5))

    # Plot training & validation loss values
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss_hist['train'], label='Train Loss')
    plt.plot(epochs, loss_hist['test'], label='Test Loss')
    plt.title('Loss History')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training & validation accuracy values
    plt.subplot(1, 2, 2)
    plt.plot(epochs, acc_hist['train'], label='Train Accuracy')
    plt.plot(epochs, acc_hist['test'], label='Test Accuracy')
    plt.title('Accuracy History')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Call the function with your loss_hist and acc_hist
plot_training_history(loss_history_ft, acc_history_ft)
# plot_training_history(loss_history_conv5, acc_history_conv5)
# plot_training_history(loss_history_ft_all, acc_history_ft_all)
# plot_training_history(loss_history_rt, acc_history_rt)

# %%
def visualize_model(model, test_dataloader, num_images=6):
    was_training = model.training
    clsname = os.listdir('./facescrub_periocular/facescrub_periocular')
    model.eval()
    images_so_far = 0
    fig = plt.figure(figsize=(15, 15))

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {clsname[preds[j]]}')
                
                # Convert from (C, H, W) to (H, W, C)
                img = inputs.cpu().data[j].numpy().transpose((1, 2, 0))
                # Reverse the normalization (assuming images were normalized)
                img = img * 0.5 + 0.5  # assuming the normalization was done using mean=0.5, std=0.5
                ax.imshow(img)

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_ft,test_dataloader)
visualize_model(model_conv5,test_dataloader)
visualize_model(model_ft_all,test_dataloader)
visualize_model(model_rt,test_dataloader)

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
from pytorch_grad_cam import GradCAM, AblationCAM,LayerCAM,ScoreCAM
# Define image size
img_size = (50, 150)

model = model_softmax #baseline
# model = model_ft_all # finetune all
# model = model_rt # retrain all
# Set the model to evaluation mode
model.eval()

# Load image
# image = Image.open("./human1.png").convert('RGB')
image = Image.open("./human2.png").convert('RGB')
# image = Image.open("./human1-1.png").convert('RGB')  # Ensure the image is in RGB mode
# image = Image.open("./human2-2.png").convert('RGB')
original_size = image.size 
image = cv2.resize(np.array(image), (img_size[1], img_size[0]))
dataset = FACEDATASET(split=None)

# Define transforms
test_transforms = T.Compose([
    transforms.ToTensor(),
    normalize
])

# Apply transforms to the image
image_tensor = test_transforms(image)

# Plotting the results
fig = plt.figure(tight_layout=True, figsize=(16,16))
rows = 1
cols = 2

# Original image
ax1 = fig.add_subplot(rows, cols, 1)
ax1.imshow(np.array(image))
ax1.set_title("Original Image")
ax1.axis("off")

# Prepare image tensor
image_tensor = image_tensor.unsqueeze(0).to(device)
# model.to(device)
# Check devices
print(f"Tensor is on device: {image_tensor.device}")
print(f"Model is on device: {next(model.parameters()).device}")

# Grad-CAM
gradcam = ScoreCAM(model=model, target_layers=[model.layer4[-1]])
# gradcam = GradCAM(model=model, target_layers=[model.layer4[-1]])
grayscale_cam = gradcam(input_tensor=image_tensor)

# # Reverse the colormap
# grayscale_cam = 1 - grayscale_cam

# Debugging: Print shapes
print(f"Original image size: {original_size}")
print(f"Resized image shape: {np.array(image).shape}")
print(f"Image tensor shape: {image_tensor.shape}")
print(f"Grayscale CAM shape: {grayscale_cam.shape}")

# Ensure the image and the CAM have the same size
resized_image = cv2.resize(np.array(image), (img_size[1], img_size[0]))
visualization2 = show_cam_on_image(resized_image/255.0,grayscale_cam[0,:])

# Resize back to the original image size
visualization2 = cv2.resize(visualization2, original_size)

# Display Grad-CAM
ax2 = fig.add_subplot(rows, cols, 2)
ax2.imshow(visualization2)
ax2.set_title("Grad-CAM")
ax2.axis("off")

plt.show()
# Out:
# Tensor is on device: cuda:1
# Model is on device: cuda:1
# 100%|██████████| 32/32 [00:00<00:00, 45.75it/s]
# Original image size: (261, 289)
# Resized image shape: (50, 150, 3)
# Image tensor shape: torch.Size([1, 3, 50, 150])
# Grayscale CAM shape: (1, 50, 150)

# %%
len(grayscale_cam[0,:])
# Out:
# 162
